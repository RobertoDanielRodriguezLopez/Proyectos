# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('C:/Users/Dan/github/Dano/HomeworksM3/OTLIERS MAX.csv',delimiter=',')
df.head(5)
# Out:
#    IdVenta       Fecha Fecha_Entrega  IdCanal  IdCliente  IdSucursal  \
# 0       20  2019-10-21    2019-10-24        2        667          13
# 1       84  2015-02-07    2015-02-12        3        993          13
# 2      101  2017-06-17    2017-06-21        2       1043          13
# 3      155  2019-03-14    2019-03-21        1        974          13
# 4      160  2019-07-09    2019-07-10        2       2689          13
#
#    IdEmpleado  IdProducto  Precio  Cantidad  Outlier  promedio  maximo
# 0    13001674       42992   570.0        30        0      2.49   11.90
# 1    13001674       42884   498.0        20        0      2.48   11.39
# 2    13001674       42883   498.0        20        0      2.30   10.82
# 3    13001674       42938  2679.0        20        0      2.07    6.52
# 4    13001674       42920   789.0        20        0      2.20    7.90

# %%
df.plot.scatter(x= 'IdProducto', y= 'maximo', alpha=0.2)
# Out:
# <AxesSubplot: xlabel='IdProducto', ylabel='maximo'>
