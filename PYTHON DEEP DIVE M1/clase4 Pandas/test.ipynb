# %%
import pandas as pd

# %%
pd.read_csv('hospitales.csv', sep = ',')
# Out:
#      LONGITUD    LATITUD                                             NOMBRE  \
# 0  -58.377552 -34.628850        HOSPITAL GENERAL DE NIÑOS PEDRO DE ELIZALDE
# 1  -58.412070 -34.594193        HOSPITAL GENERAL DE NIÑOS RICARDO GUTIERREZ
# 2  -58.402730 -34.584530  HOSPITAL DE ODONTOLOGIA DR. RAMON CARRILLO (EX...
# 3  -58.385155 -34.639404            HOSPITAL DE SALUD MENTAL BRAULIO MOYANO
# 4  -58.391310 -34.634155           HOSPITAL DE GASTROENTEROLOGIA B. UDAONDO
# 5  -58.434944 -34.608470                   INSTITUTO DE ZOONOSIS L. PASTEUR
# 6  -58.375843 -34.630210  HOSPITAL DE REHABILITACION RESPIRATORIA MARIA ...
# 7  -58.382328 -34.635704           HOSPITAL INFANTO JUVENIL C. TOBAR GARCIA
# 8  -58.382130 -34.636436               HOSPITAL DE SALUD MENTAL J. T. BORDA
# 9  -58.360120 -34.638893  HOSPITAL DE ODONTOLOGIA INFANTIL DON BENITO QU...
# 10 -58.440987 -34.553898  INSTITUTO DE REHABILITACION PSICOFISICA (I.R.E...
# ...
