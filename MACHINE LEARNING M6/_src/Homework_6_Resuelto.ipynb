# %% [markdown]
# Los resultados del modelo del Homework 5, de la clase 3 fueron satisfactorios, pero se tiene interés en conocer si aplicando redes neuronales se pueden obtener mejores clasificadores.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
sns.set()

# %%
from IPython.display import clear_output

# %%
df_conversiones = pd.read_csv("../Datasets/conversiones.csv", sep=",")

# %%
df_conversiones.head()
# Out:
#    Costo1  Costo2  Topico  Quincena  TipoProducto Conversion
# 0   0.341   0.299       2         7             1         Si
# 1   0.151   0.079       2         8             1         Si
# 2   0.384   0.324       4         9             1         Si
# 3   0.200   0.192       4         9             1         Si
# 4   0.415   0.020       2         8             1         Si

# %%
df_conversiones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319946 entries, 0 to 319945
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Costo1        319946 non-null  float64
#  1   Costo2        319946 non-null  float64
#  2   Topico        319946 non-null  int64
#  3   Quincena      319946 non-null  int64
#  4   TipoProducto  319946 non-null  int64
#  5   Conversion    319946 non-null  object
# dtypes: float64(2), int64(3), object(1)
# memory usage: 14.6+ MB

# %%
df_conversiones.describe()
# Out:
#               Costo1         Costo2         Topico       Quincena  \
# count  319946.000000  319946.000000  319946.000000  319946.000000
# mean        0.349474       0.361730       2.966194      12.845168
# std         0.270063       0.278102       1.172870       6.493443
# min         0.000000       0.000000       1.000000       1.000000
# 25%         0.134000       0.138000       2.000000       7.000000
# 50%         0.273000       0.280000       3.000000      13.000000
# 75%         0.502000       0.556000       4.000000      19.000000
# max         1.000000       1.000000       5.000000      24.000000
#
#         TipoProducto
# count  319946.000000
# mean        4.502994
# std         2.179622
# min         1.000000
# 25%         3.000000
# 50%         5.000000
# 75%         6.000000
# max         8.000000

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df_conversiones['Conversion'] = le.fit_transform(df_conversiones['Conversion'])

# %%
df_conversiones['Topico'] = df_conversiones['Topico'] / 5

# %%
df_conversiones['Quincena'] = df_conversiones['Quincena'] / 24

# %%
df_conversiones['TipoProducto'] = df_conversiones['TipoProducto'] / 8

# %%
df_conversiones.describe()
# Out:
#               Costo1         Costo2         Topico       Quincena  \
# count  319946.000000  319946.000000  319946.000000  319946.000000
# mean        0.349474       0.361730       0.593239       0.535215
# std         0.270063       0.278102       0.234574       0.270560
# min         0.000000       0.000000       0.200000       0.041667
# 25%         0.134000       0.138000       0.400000       0.291667
# 50%         0.273000       0.280000       0.600000       0.541667
# 75%         0.502000       0.556000       0.800000       0.791667
# max         1.000000       1.000000       1.000000       1.000000
#
#         TipoProducto     Conversion
# count  319946.000000  319946.000000
# mean        0.562874       0.499934
# std         0.272453       0.500001
# min         0.125000       0.000000
# 25%         0.375000       0.000000
# 50%         0.625000       0.000000
# 75%         0.750000       1.000000
# max         1.000000       1.000000

# %%
def plot_corre_heatmap(corr):
    '''
    Definimos una función para ayudarnos a graficar un heatmap de correlación
    '''
    plt.figure(figsize=(12,10))
    sns.heatmap(corr, cbar = True,  square = False, annot=True, fmt= '.2f'
                ,annot_kws={'size': 15},cmap= 'coolwarm')
    plt.xticks(rotation = 45)
    plt.yticks(rotation = 45)
    # Arreglamos un pequeño problema de visualización
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show()

# %%
corr = df_conversiones.corr()
plot_corre_heatmap(corr)

# %%
sns.countplot(x='Conversion', data=df_conversiones) #equivelante a sns.countplot(df_conversiones.Conversion)
plt.show()

# %%
sns.pairplot(df_conversiones, hue = 'Conversion')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_conversiones[['Costo1','Costo2','Topico','Quincena','TipoProducto']]
y = df_conversiones['Conversion']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify = y)

# %%
X_train.shape
# Out:
# (255956, 5)

# %%
from keras import models
from keras import layers
from keras.utils.vis_utils import plot_model

# %%
red = models.Sequential()
red.add(layers.Dense(5, activation='relu', input_shape=(5,)))
#red.add(layers.Dense(3, activation='relu'))
red.add(layers.Dense(1, activation='sigmoid'))

# %%
red.compile(optimizer='rmsprop',
                       loss='binary_crossentropy',
                       metrics=['acc'])

# %%
plot_model(red, show_shapes=True, show_layer_names=True) #to_file='red.png',
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
entrenamiento = red.fit(X_train, y_train, epochs=80, batch_size=512, validation_data=(X_test, y_test))
# Out:
# Epoch 1/80
# 500/500 [==============================] - 2s 2ms/step - loss: 0.6203 - acc: 0.6721 - val_loss: 0.5111 - val_acc: 0.8198
# Epoch 2/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.4502 - acc: 0.8216 - val_loss: 0.4138 - val_acc: 0.8256
# Epoch 3/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.4096 - acc: 0.8243 - val_loss: 0.4037 - val_acc: 0.8278
# Epoch 4/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.4022 - acc: 0.8258 - val_loss: 0.3959 - val_acc: 0.8295
# Epoch 5/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3958 - acc: 0.8279 - val_loss: 0.3918 - val_acc: 0.8305
# Epoch 6/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3926 - acc: 0.8299 - val_loss: 0.3892 - val_acc: 0.8318
# Epoch 7/80
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3900 - acc: 0.8322 - val_loss: 0.3864 - val_acc: 0.8339
# Epoch 8/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3872 - acc: 0.8347 - val_loss: 0.3834 - val_acc: 0.8361
# Epoch 9/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3843 - acc: 0.8362 - val_loss: 0.3804 - val_acc: 0.8381
# Epoch 10/80
# Epoch 67/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3702 - acc: 0.8368 - val_loss: 0.3679 - val_acc: 0.8380
# Epoch 68/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3702 - acc: 0.8367 - val_loss: 0.3679 - val_acc: 0.8383
# Epoch 69/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3702 - acc: 0.8367 - val_loss: 0.3679 - val_acc: 0.8381
# Epoch 70/80
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3702 - acc: 0.8366 - val_loss: 0.3683 - val_acc: 0.8400
# Epoch 71/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3702 - acc: 0.8369 - val_loss: 0.3680 - val_acc: 0.8385
# Epoch 72/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3702 - acc: 0.8369 - val_loss: 0.3679 - val_acc: 0.8376
# Epoch 73/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3702 - acc: 0.8367 - val_loss: 0.3680 - val_acc: 0.8392
# Epoch 74/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3702 - acc: 0.8366 - val_loss: 0.3679 - val_acc: 0.8381
# Epoch 75/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3702 - acc: 0.8369 - val_loss: 0.3680 - val_acc: 0.8393
# Epoch 76/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3702 - acc: 0.8366 - val_loss: 0.3679 - val_acc: 0.8387
# Epoch 77/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3702 - acc: 0.8366 - val_loss: 0.3682 - val_acc: 0.8402
# Epoch 78/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3702 - acc: 0.8366 - val_loss: 0.3679 - val_acc: 0.8392
# Epoch 79/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3702 - acc: 0.8365 - val_loss: 0.3682 - val_acc: 0.8396
# Epoch 80/80
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3702 - acc: 0.8367 - val_loss: 0.3681 - val_acc: 0.8370

# %%
epochs = range(1, 81)
loss = entrenamiento.history['loss']
acc = entrenamiento.history['acc']
val_loss = entrenamiento.history['val_loss']
val_acc = entrenamiento.history['val_acc']

# %%
# b+ is for "blue cross"
plt.plot(epochs, acc, 'b+', label='Entrenamiento')
# "bo" is for "blue dot"
plt.plot(epochs, val_acc, 'bo', label='Validacion')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# b+ is for "blue cross"
plt.plot(epochs, loss, 'b+', label='Entrenamiento')
# "bo" is for "blue dot"
plt.plot(epochs, val_loss, 'bo', label='Validacion')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
test_loss, test_acc = red.evaluate(X_test, y_test)
# Out:
# 2000/2000 [==============================] - 2s 1ms/step - loss: 0.3681 - acc: 0.8370

# %%
print('test_acc:', test_acc)
# Out:
# test_acc: 0.8370214104652405
