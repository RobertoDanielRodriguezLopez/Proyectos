# %% [markdown]
# # Epoch, Batch Size e Iteración

# %% [markdown]
# En la terminología de la red neuronal:
#
# * `Epoch ó Época:` un pase hacia adelante (forward propagation) y un pase hacia atrás (backpropagation) de todos los ejemplos de entrenamiento.
# * `Batch Size ó Tamaño de Lote:` el número de ejemplos de entrenamiento en un pase hacia adelante/atrás. Cuanto mayor sea el tamaño del lote, más espacio de memoria necesitará.
# * `Número de Iteraciones:` número de pases, cada pase usando un número de ejemplos del tamaño del Batch Size. Para ser claros, __un pase = un pase hacia adelante + un pase hacia atrás__ (no contamos el pase hacia adelante y hacia atrás como dos pases diferentes).
#
# ## Ejemplo:
# Si se tienen 1000 datos de entrenamiento y el tamaño de su lote (Batch Size) es 500, se necesitarán 2 iteraciones para completar 1 época.

# %% [markdown]
# # Propagación hacia adelante y hacia atrás

# %% [markdown]
# Supongamos que tenemos un perceptrón con `2 entradas`, y una salida, la `predicción` y que nuestro conjunto de entrenamiento está formado solamente por dos datos:
#
# $$x_1 = [1,1] \\
# x_2 = [0,1] $$
#
# Y sus respectivas salidas:
#
# $$y_1 = 1 \\
# y_2 = 0$$

# %% [markdown]
# ---
# Para el primer ejemplo de entrenamiento $x_1$, la salida deseada del perceptrón `1`, y para el segundo ejemplo, es `0`. La estructura se ve así:

# %%
from IPython.display import Image
Image("Imagenes/1.png")

# %% [markdown]
# ---
# ## Propagación hacia adelante:
#
# En la propagación directa ó hacia `adelante`, verificamos qué predice el perceptró el primer ejemplo de entrenamiento con `pesos iniciales y bias`. En primer lugar debemos inicializar los pesos y el bias al azar:

# %%
Image("Imagenes/2.png")

# %% [markdown]
# Luego calculamos `z`, la suma ponderada de la entrada y el bias:

# %%
Image("Imagenes/3.png")

# %%
Image("Imagenes/4.png")

# %% [markdown]
# Después de obtener `z`, podemos aplicarle la función de activación, para nuestro ejemplo vamos a aplicar una función tangente hiperbólica:

# %%
Image("Imagenes/6.png")

# %% [markdown]
# Donde $\sigma$ es la función de activación. Las funciones de activación más comunes son `relu`, `sigmoide` y `tanh`.

# %%
Image("Imagenes/7.png")

# %%
Image("Imagenes/8.png")

# %% [markdown]
# Para el primer ejemplo de entrenamiento, nuestro perceptrón predijo el resultado `0.291`. Nuestro resultado deseado era `1`. El perceptrón se puede mejorar con el proceso de `propagación hacia atrás`. Antes de continuar con la propagación hacia atrás, calculemos la predicción para el segundo ejemplo de entrenamiento.

# %%
Image("Imagenes/10.png")

# %% [markdown]
# ---
# # Propagación hacia atrás:
#
# Podemos definir una `función de costo` que mida qué tan bien funciona nuestro perceptrón. Para una entrada, `x` y salida deseada, `y`, podemos calcular el costo de un ejemplo de entrenamiento específico como el cuadrado de la diferencia entre la salida del perceptrón y la salida deseada:

# %%
Image("Imagenes/11.png")

# %% [markdown]
# donde `k` representa el ejemplo de entrenamiento y se supone que la salida es la activación de la neurona de salida, e `y` es la salida deseada real. Para nuestros ejemplos de entrenamiento, los costos son los siguientes:

# %%
Image("Imagenes/12.png")

# %%
Image("Imagenes/13.png")

# %% [markdown]
# El costo total de un conjunto de entrenamiento es el promedio de las funciones de costo individuales de los datos en el conjunto de entrenamiento:

# %%
Image("Imagenes/14.png")

# %% [markdown]
# donde `N` representa el número de ejemplos de entrenamiento.

# %%
Image("Imagenes/15.png")

# %% [markdown]
# Queremos mejorar el rendimiento del perceptrón cambiando los `pesos` y el `bias` y, con suerte, reducir el costo total.
#
# Por lo tanto debemos saber cuánto afectan los pesos específicos y el bias al costo total, por lo que debemos calcular las `derivadas parciales del costo total con respecto a los pesos y el bias`.
#
# Para hacer esto, vamos a aplicar la `regla de la cadena`

# %%
Image("Imagenes/16.png")

# %%
Image("Imagenes/17.png")

# %%
Image("Imagenes/18.png")

# %% [markdown]
# El cálculo de las derivadas parciales para el primer ejemplo de entrenamiento:

# %%
Image("Imagenes/19.png")

# %%
Image("Imagenes/20.png")

# %%
Image("Imagenes/21.png")

# %% [markdown]
# Las derivadas parciales para el segundo ejemplo de entrenamiento:

# %%
Image("Imagenes/22.png")

# %%
Image("Imagenes/23.png")

# %%
Image("Imagenes/24.png")

# %% [markdown]
# Ahora, calculamos las `derivadas parciales con respecto al costo total`.
#
# Considere el primer peso ($w_1$). La derivada parcial del costo total con respecto a $w_1$ es el promedio de todas las derivadas parciales de las funciones de costo individuales con respecto a $w_1$:

# %%
Image("Imagenes/25.png")

# %%
Image("Imagenes/26.png")

# %%
Image("Imagenes/27.png")

# %%
Image("Imagenes/28.png")

# %% [markdown]
# Luego `actualizamos los pesos y el bias`, multiplicamos las derivadas parciales con cierta tasa de aprendizaje ($\alpha$) y restamos los resultados de los pesos y el bias.
#
# Vamos a usar una tasa de aprendizaje $\alpha=0.6$

# %%
Image("Imagenes/29.png")

# %%
Image("Imagenes/30.png")

# %%
Image("Imagenes/31.png")

# %%
Image("Imagenes/32.png")

# %% [markdown]
# Después de actualizar los pesos y el sesgo, nuestra red neuronal se ve así:

# %%
Image("Imagenes/33.png")

# %% [markdown]
# ### Este es el final de la primera iteración de la propagación hacia atrás. Podríamos continuar con la propagación hacia adelante, calcular el costo y luego volver a la propagación hacia atrás nuevamente.
